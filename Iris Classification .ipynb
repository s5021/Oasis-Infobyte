# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\sonu\Desktop\IRIS.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df['Species'],categories = pd.factorize(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]>

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
## there is nonull values in the entire datasets

# %% [markdown]
# ## Data Visualization

# %%
# Histogram

# %%
df.hist()
plt.show()

# %%
# there is no use of id so we drop this column from the datasets

# %%
df.drop('Id', axis='columns', inplace=True)

# %%
df.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0
# 5            5.4           3.9            1.7           0.4        0
# 6            4.6           3.4            1.4           0.3        0
# 7            5.0           3.4            1.5           0.2        0
# 8            4.4           2.9            1.4           0.2        0
# 9            4.9           3.1            1.5           0.1        0

# %%
# Scatter plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %%
# 3d plot of petallength, petalwidth and species

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(df.PetalLengthCm, df.PetalWidthCm, df.Species)
ax.set_xlabel('PetalLengthCm')
ax.set_ylabel('PetalWidthCm')
ax.set_zlabel('Species')
plt.title('3d Scatter Plot Example')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(df.SepalLengthCm, df.SepalWidthCm, df.Species)
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
ax.set_zlabel('Species')
plt.title('3d Scatter Plot Example')
plt.show()

# %%
sns.scatterplot(data = df, x = "PetalLengthCm", y = "PetalWidthCm", hue = "Species");

# %%
sns.scatterplot(data = df, x = "SepalLengthCm", y = "SepalWidthCm", hue = "Species");

# %%
# Regression line

# %%
plt.figure(figsize = (8,6))
sns.regplot(x = 'PetalLengthCm',y = 'SepalLengthCm', data = df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize = (8,6))
sns.regplot(x = 'PetalWidthCm',y = 'SepalWidthCm', data = df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
# Correlation

# %%
newdf = df.drop(columns = 'Species', axis = 1)
newdf.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# there is no value that's why its show same colur of the entire dataset

# %%
X = df.iloc[:,[0,4]].values
y = df.iloc[:,4].values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode = LabelEncoder()
y = encode.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 52)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 4)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
A = accuracy_score(y_pred,y_test)

# %%
print(f"Accuracy score of the KNN model is : {A}")
# Out:
# Accuracy score of the KNN model is : 1.0

# %%
B = confusion_matrix(y_pred,y_test)
print(f"Confusion matrix of the KNN model is : {B}")
# Out:
# Confusion matrix of the KNN model is : [[11  0  0]
#  [ 0 17  0]
#  [ 0  0 17]]
